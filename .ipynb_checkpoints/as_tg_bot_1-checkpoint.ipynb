# %%
import asyncio
from aiogram import Bot, Dispatcher, types
import nest_asyncio # Позволяет использовать вложенные циклы событий в asyncio 
                    # при RuntimeError: asyncio.run() cannot be called from a running event loop

nest_asyncio.apply()

dp = Dispatcher()

@dp.message()
async def echo_handler(message: types.Message) -> None:
    await message.answer('Подождите, пожалуйста, я думаю...')
    await asyncio.sleep(3)
    await message.send_copy(chat_id=message.chat.id)

async def main() -> None:
    token = "6788998199:AAGWzyV_At5kanF3tOybM2HpFNDg_-5NjOQ"
    bot = Bot(token)
    await dp.start_polling(bot)

if __name__ == "__main__":
    asyncio.run(main())

# %%
# !pip install aiogram asyncio

# %%
import asyncio
from aiogram import Bot, Dispatcher, types
from aiogram.filters import Command #Object ??? Обработчик команд
import nest_asyncio # Позволяет использовать вложенные циклы событий в asyncio 
                    # при RuntimeError: asyncio.run() cannot be called from a running event loop

nest_asyncio.apply()

dp = Dispatcher()

@dp.message(Command('name1'))
@dp.message(Command('name2'))
@dp.message(Command('name'))
async def echo_handler(message: types.Message) -> None:
    await message.answer('Подождите, пожалуйста, я думаю...')
    

async def main() -> None:
    token = "6788998199:AAGWzyV_At5kanF3tOybM2HpFNDg_-5NjOQ"
    bot = Bot(token)
    await dp.start_polling(bot)

if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
from aiogram import Bot, Dispatcher, types
from aiogram import F
import nest_asyncio # Позволяет использовать вложенные циклы событий в asyncio 
                    # при RuntimeError: asyncio.run() cannot be called from a running event loop

nest_asyncio.apply()

dp = Dispatcher()

@dp.message(F.text.startswith("яблоко")) # Принимает любые сообщения, начинающиеся со слова "яблоко" 
async def echo_handler(message: types.Message) -> None:
    await message.answer('Подождите, пожалуйста, я думаю...')
    await asyncio.sleep(3)
    await message.send_copy(chat_id=message.chat.id)

async def main() -> None:
    token = "6788998199:AAGWzyV_At5kanF3tOybM2HpFNDg_-5NjOQ"
    bot = Bot(token)
    await dp.start_polling(bot)

if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
import nest_asyncio
from aiogram import Bot, Dispatcher, types, F
from aiogram.filters import Command

dp = Dispatcher()
nest_asyncio.apply()

@dp.message(Command('start'))
async def start_command(message: types.Message) -> None:
    await message.answer(f'Добрый день, {message.from_user.full_name}\nРад вас видеть, напишите Меню, чтобы узнать мои команды')

@dp.message(F.text == 'Меню')
async def menu_handler(message: types.Message) -> None:
    await message.answer('Мои команды\n\nПривет - я тебе отвечу привет!\nМорс - я расскажу о том, какой вкусный облепиховый морс')

@dp.message(F.text == 'Привет')
async def hello_handler(message: types.Message) -> None:
    await message.answer('Привет! Как у тебя дела?')

@dp.message(F.text == 'Морс')
async def morse_handler(message: types.Message) -> None:
    await message.answer('Ты не представляешь какой вкусный морс я сегодня пил. Мне кажется, он вызывает зависимость')

@dp.message()
async def all_handler(message: types.Message) -> None:
    await message.answer('Я ловлю всех и вся')
    
async def main() -> None:
    token = "6788998199:AAGWzyV_At5kanF3tOybM2HpFNDg_-5NjOQ"
    bot = Bot(token)
    await dp.start_polling(bot)


if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
import nest_asyncio
from aiogram import Bot, Dispatcher, types, F
from aiogram.filters import Command

dp = Dispatcher()
nest_asyncio.apply()

@dp.message(Command("start"))
async def cmd_start(message: types.Message):
    kb = [                                                    #Положение кнопок управляется порядком их размещения в списках:
         [types.KeyboardButton(text="С пюрешкой"),            #Каждый внутренний список в keyboard представляет собой один горизонтальный ряд кнопок.
         types.KeyboardButton(text="Без пюрешки"),            #row_width в ReplyKeyboardMarkup можно использовать для указания 
         types.KeyboardButton(text="С капусткой")]            #максимального количества кнопок в одном ряду. 
    ]                                                         #Если вы не задаете row_width, все кнопки из списка будут размещены в одной строке. 
   
    keyboard = types.ReplyKeyboardMarkup(keyboard=kb, resize_keyboard=True, row_width=1)
    await message.answer("Как подавать котлеты?", reply_markup=keyboard)

@dp.message(F.text == 'Меню')
async def menu_handler(message: types.Message) -> None:
    await message.answer('Мои команды\n\n'
                         'Обо мне - я вышлю всё, что знаю о себе\n'
                         'Имя - я расскажу о том, как меня зовут\n'
                         'Портфолио - я вышлю ботов, которых я сделал\n'
                         'О тебе - а здесь самое интересное, я расскажу всё, что знаю о тебе')


@dp.message(F.text == 'Обо мне')
async def about_me_handler(message: types.Message) -> None:
    await message.answer('Рад, что ты спросил\n'
                         'Я на самом деле редко говорю о себе, но мама говорит, что я классный')


@dp.message(F.text == 'Имя')
async def name_handler(message: types.Message, bot: Bot) -> None:
    await message.answer(f'Меня зовут {(await bot.get_me()).full_name}. '
                         f'А как тебя зовут? Хотя, можешь не отвечать, я не смогу прочитать')


@dp.message(F.text == 'Портфолио')
async def portfolio_handler(message: types.Message) -> None:
    await message.answer('Я пока что только учусь, и ещё не успел создать ботов, но скоро они здесь будут')


@dp.message(F.text == 'О тебе')
async def about_you_handler(message: types.Message) -> None:
    await message.answer(f'А тебя зовут {message.from_user.full_name}!')


async def main() -> None:
    token = "6788998199:AAGWzyV_At5kanF3tOybM2HpFNDg_-5NjOQ"
    bot = Bot(token)
    await dp.start_polling(bot)


if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
import nest_asyncio
from aiogram import Bot, Dispatcher, types, F
from aiogram.filters import Command

dp = Dispatcher()
nest_asyncio.apply()
token = "6788998199:AAGWzyV_At5kanF3tOybM2HpFNDg_-5NjOQ"
bot = Bot(token)

@dp.message(Command('start'))
async def start_command(message: types.Message) -> None:
    kb = [
        [types.KeyboardButton(text="Обо мне")],

        [
            types.KeyboardButton(text="Имя"),
            types.KeyboardButton(text="Портфолио")
        ],
        [
            types.KeyboardButton(text="О тебе")
        ]
    ]
    keyboard = types.ReplyKeyboardMarkup(keyboard=kb, resize_keyboard=True)
    await message.answer('Привет! это мой бот-визитка', reply_markup=keyboard)


@dp.message(F.text == 'Обо мне')
async def about_me_handler(message: types.Message) -> None:
    await message.answer('Рад, что ты спросил\n'
                         'Я на самом деле редко говорю о себе, но мама говорит, что я классный')


@dp.message(F.text == 'Имя')
async def name_handler(message: types.Message, bot: Bot) -> None:
    await message.answer(f'Меня зовут {(await bot.get_me()).full_name}. '
                         f'А как тебя зовут? Хотя, можешь не отвечать, я не смогу прочитать')


@dp.message(F.text == 'Портфолио')
async def portfolio_handler(message: types.Message) -> None:
    await message.answer('Я пока что только учусь, и ещё не успел создать ботов, но скоро они здесь будут')


@dp.message(F.text == 'О тебе')
async def about_you_handler(message: types.Message) -> None:
    await message.answer(f'А тебя зовут {message.from_user.full_name}!')


async def main() -> None:
    # token = "6788998199:AAGWzyV_At5kanF3tOybM2HpFNDg_-5NjOQ"
    # bot = Bot(token)
    await dp.start_polling(bot)


if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
import nest_asyncio
from aiogram import Bot, Dispatcher, types, F
from aiogram.filters import Command
from config_bot_tg import TOKEN        # Импорт TOKEN из файла config_bot_tg.py

dp = Dispatcher()
nest_asyncio.apply()
bot = Bot(token = TOKEN)

@dp.message(Command('start'))
async def start_command(message: types.Message) -> None:
    kb = [
        [types.InlineKeyboardButton(text="Обо мне", callback_data='about_me')],

        [
            types.InlineKeyboardButton(text="Имя", callback_data='name'),
            types.InlineKeyboardButton(text="Портфолио", url='https://github.com/Anatoliy0461/Malon')
        ],
        [
            types.InlineKeyboardButton(text="О тебе", callback_data='about_you')
        ]
    ]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await message.answer('Привет! это мой бот-визитка', reply_markup=keyboard)

@dp.callback_query(F.data == "about_me")
async def about_me_callback(callback: types.CallbackQuery):
    await callback.message.edit_text('Рад, что ты спросил\n'
                                     'Я на самом деле редко говорю о себе, но мама говорит, что я классный')

@dp.callback_query(F.data == 'name')
async def name_callback(callback: types.CallbackQuery):
    await callback.message.answer(f'Меня зовут {(await bot.get_me()).full_name}. '
                         f'А как тебя зовут? Хотя, можешь не отвечать, я не смогу прочитать')

@dp.callback_query(F.data == 'portfolio')
async def portfolio_callback(callback: types.CallbackQuery):
    await callback.message.answer('Я пока что только учусь, и ещё не успел создать ботов, но скоро они здесь будут')

@dp.callback_query(F.data == 'about_you')
async def about_you_callback(callback: types.CallbackQuery):
    await callback.message.answer(f'А тебя зовут {callback.from_user.full_name}!')

async def main() -> None:
     await dp.start_polling(bot)


if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
import nest_asyncio
from aiogram import Bot, Dispatcher, types, F
from aiogram.filters import Command
from dotenv import find_dotenv, load_dotenv        
import os

load_dotenv(find_dotenv())                        # Находим .env

dp = Dispatcher()
nest_asyncio.apply()
bot = Bot(token = os.getenv('TOKEN'))             # Подставляем значение из .env

@dp.message(Command('start'))
async def start_command(message: types.Message) -> None:
    kb = [
        [types.InlineKeyboardButton(text="Обо мне", callback_data='about_me')],

        [
            types.InlineKeyboardButton(text="Имя", callback_data='name'),
            types.InlineKeyboardButton(text="Портфолио", url='https://github.com/Anatoliy0461/Malon')
        ],
        [
            types.InlineKeyboardButton(text="О тебе", callback_data='about_you')
        ]
    ]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await message.answer('Привет! это мой бот-визитка', reply_markup=keyboard)

@dp.callback_query(F.data == "about_me")
async def about_me_callback(callback: types.CallbackQuery):
    await callback.message.edit_text('Рад, что ты спросил\n'
                                     'Я на самом деле редко говорю о себе, но мама говорит, что я классный')

@dp.callback_query(F.data == 'name')
async def name_callback(callback: types.CallbackQuery):
    await callback.message.answer(f'Меня зовут {(await bot.get_me()).full_name}. '
                         f'А как тебя зовут? Хотя, можешь не отвечать, я не смогу прочитать')

@dp.callback_query(F.data == 'portfolio')
async def portfolio_callback(callback: types.CallbackQuery):
    await callback.message.answer('Я пока что только учусь, и ещё не успел создать ботов, но скоро они здесь будут')

@dp.callback_query(F.data == 'about_you')
async def about_you_callback(callback: types.CallbackQuery):
    await callback.message.answer(f'А тебя зовут {callback.from_user.full_name}!')

async def main() -> None:
     await dp.start_polling(bot)


if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
import nest_asyncio
from aiogram import Bot, Dispatcher, types, F
from aiogram.filters import Command
from dotenv import find_dotenv, load_dotenv        
import os

load_dotenv(find_dotenv())                        # Находим .env

dp = Dispatcher()
nest_asyncio.apply()
bot = Bot(token = os.getenv('TOKEN'))             # Подставляем значение из .env

menu = [                                                    
     [types.KeyboardButton(text="Каталог")],            
     [types.KeyboardButton(text="Профиль"), types.KeyboardButton(text="Тех.поддержка", url='https://github.com/Anatoliy0461/Malon')],            
     [types.KeyboardButton(text="О нас")]             
    ]   
@dp.message(Command('start'))
async def cmd_start(message: types.Message):
    keyboard = types.ReplyKeyboardMarkup(keyboard=menu, resize_keyboard=True, row_width=1)
    await message.answer("Привет-привет!", reply_markup=keyboard)

########## Кнопка Каталог ##########################
####################################################
@dp.message(F.text == 'Каталог')
async def menu_handler(message: types.Message) -> None:
    kb = [
        [
            types.InlineKeyboardButton(text="Курс по Python", callback_data='Python'),
            types.InlineKeyboardButton(text="Курс по Telebot", callback_data='Telebot')
        ],
        [   
            types.InlineKeyboardButton(text="Курс по Aiogram", callback_data='Aiogram'),
            types.InlineKeyboardButton(text="Курс по Django", callback_data='Django')
        ]
    ]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await message.answer('Выбери курс', reply_markup=keyboard)    

########## Покупка курса Python ##########################
@dp.callback_query(F.data == "Python")
async def Python_callback(callback: types.CallbackQuery):
    kb = [[types.InlineKeyboardButton(text="Купить", callback_data='Buy')]]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await callback.message.answer('Курс по Python\n'
                                     'Для вас будет стоить 100$', reply_markup=keyboard)
@dp.callback_query(F.data == "Buy")
async def Buy_callback(callback: types.CallbackQuery):
    await callback.message.answer('Спасибо за покупку,\n'
                                     'курс успешно куплен')

########## Покупка курса Telebot ##########################
@dp.callback_query(F.data == "Telebot")
async def Telebot_callback(callback: types.CallbackQuery):
    kb = [[types.InlineKeyboardButton(text="Купить", callback_data='Buy')]]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await callback.message.answer('Курс по Telebot\n'
                                     'Для вас будет стоить 100$', reply_markup=keyboard)
@dp.callback_query(F.data == "Buy")
async def Buy_callback(callback: types.CallbackQuery):
    await callback.message.answer('Спасибо за покупку,\n'
                                     'курс успешно куплен')

########## Покупка курса Aiogram ##########################
@dp.callback_query(F.data == "Aiogram")
async def Aiogram_callback(callback: types.CallbackQuery):
    kb = [[types.InlineKeyboardButton(text="Купить", callback_data='Buy')]]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await callback.message.answer('Курс по Aiogram\n'
                                     'Для вас будет стоить 100$', reply_markup=keyboard)
@dp.callback_query(F.data == "Buy")
async def Buy_callback(callback: types.CallbackQuery):
    await callback.message.answer('Спасибо за покупку,\n'
                                     'курс успешно куплен')

########## Покупка курса Django ##########################
@dp.callback_query(F.data == "Django")
async def Django_callback(callback: types.CallbackQuery):
    kb = [[types.InlineKeyboardButton(text="Купить", callback_data='Buy')]]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await callback.message.answer('Курс по Django\n'
                                     'Для вас будет стоить 100$', reply_markup=keyboard)
@dp.callback_query(F.data == "Buy")
async def Buy_callback(callback: types.CallbackQuery):
    await callback.message.answer('Спасибо за покупку,\n'
                                     'курс успешно куплен')

########## Кнопка Профиль ##########################
####################################################
@dp.message(F.text == 'Профиль')
async def menu_handler(message: types.Message) -> None:
    kb = [[types.InlineKeyboardButton(text="Возврат в меню", callback_data='Back')]]
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=kb, resize_keyboard=True)
    await message.answer(f'Профиль: {message.from_user.full_name}!, \n'
                        f'id: {message.from_user.id} \n'
                        f'Баланс ', reply_markup=keyboard)
@dp.callback_query(F.data == "Back")
async def back_to_menu(callback: types.CallbackQuery):
    keyboard = types.ReplyKeyboardMarkup(keyboard=menu, resize_keyboard=True, row_width=1)
    await callback.message.answer("Вернулись в меню", reply_markup=keyboard)

########## Кнопка Тех.поддержка ####################
####################################################
# @dp.message(F.text == 'Тех.поддержка')                                       # Без кнопки url
# async def tech_support(message: types.Message):
#     await message.answer("Если у вас возникли проблемы, вы можете обратиться в техподдержку по ссылке:")
#     await bot.send_message(message.chat.id, "https://github.com/Anatoliy0461/Malon")

@dp.message(F.text == 'Тех.поддержка')                                         # C кнопкой url
async def tech_support(message: types.Message):
    await message.answer("Если у вас возникли проблемы, вы можете обратиться в техподдержку по ссылке:")
    url_button = types.InlineKeyboardButton(text="Техподдержка", url="https://github.com/Anatoliy0461/Malon")
    keyboard = types.InlineKeyboardMarkup(inline_keyboard=[[url_button]])
    await message.answer("Нажмите на кнопку, чтобы перейти в техподдержку:", reply_markup=keyboard)

########## Кнопка О нас ############################
####################################################
@dp.message(F.text == 'О нас')                                       
async def about_us(message: types.Message):
        await message.answer("МЫ ЛУЧШИЕ!!!")    
    

async def main() -> None:
     await dp.start_polling(bot)


if __name__ == "__main__":
    asyncio.run(main())

# %%
import asyncio
import nest_asyncio
from aiogram import Bot, Dispatcher, types, F
from aiogram.filters import Command
from dotenv import find_dotenv, load_dotenv        
import os
from aiogram.types import FSInputFile
load_dotenv(find_dotenv())                        

dp = Dispatcher()
nest_asyncio.apply()
bot = Bot(token = os.getenv('TOKEN'))             

@dp.message(F.text == 'Ода голосу')
async def oda_handler(message: types.Message):
    photo = FSInputFile('Изображение WhatsApp 2024-04-17 в 09.38.47_daae3648.jpg')
    message_data = await message.answer_photo(photo)   # Отправляем photo по запросу 'Ода голосу'
    print("file_id:", message_data.photo[-1].file_id)              # Получаем file_id отправленного photo

async def main() -> None:
     await dp.start_polling(bot)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# file_id: AgACAgIAAxkDAAIIzGYhdgI8CYGh4KGUYxAKTUQoh5bKAAJw4DEbWKwISa1W-x_zadNiAQADAgADeAADNAQ
